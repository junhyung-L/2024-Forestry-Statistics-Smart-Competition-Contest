# %%
# !pip install geopandas 
# !pip install fiona

# %%
import geopandas as gpd  
from fiona.crs import from_epsg
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
gdf = gpd.read_file(r"C:\Users\user\Downloads\서울특별시-20241114T095017Z-001\서울특별시\11.shp")  
gdf.head()
# Out:
#       Id  gridcode                                           geometry
# 0  20286         5  MULTIPOLYGON (((957127.423 1966674.946, 957127...
# 1  20832         2  POLYGON ((956816.377 1966457.885, 956816.217 1...
# 2  22208         2  POLYGON ((956633.62 1965929.052, 956633.567 19...
# 3  22232         2  POLYGON ((956653.293 1965868.969, 956653.239 1...
# 4  22265         2  POLYGON ((956643.243 1965859.026, 956643.19 19...

# %%
gdf_2 = gdf.to_crs(epsg=3857)

# %%
fig = plt.figure(figsize=(18, 13))
ax = fig.subplots(1, 1)
 
# 범례
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)
 
# 단계구분도
gdf.plot("gridcode", ax=ax, legend=True,  cax=cax, cmap='Blues')
ax.set_title("Seoul_sooboonhamranng", fontsize=25, pad=20)
# Out:
# Text(0.5, 1.0, 'Seoul_sooboonhamranng')
